# %%
# !git clone https://github.com/sanjugowda216/COSMOS25Project.git
# Out:
# Cloning into 'COSMOS25Project'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 120 (delta 53), reused 24 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 39.31 KiB | 774.00 KiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
import os
os.environ['GH_TOKEN'] = "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"

# %%
# %%bash
# cd /content/COSMOS25Project
#
# git config user.email "arushi.iyers@g"
# git config user.name  "Arushi Iyer"
