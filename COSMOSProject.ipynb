# %%
# !git clone https://github.com/sanjugowda216/COSMOS25Project.git
# Out:
# Cloning into 'COSMOS25Project'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 114 (delta 49), reused 22 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 37.76 KiB | 1.99 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
import os
os.environ["GH_TOKEN"] = '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'

# %%
# %%bash
# cd /content/COSMOS25Project
#
# git config user.email "soahmsrikar@gmail.com"
# git config user.name  "Soham Pinapala"

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/COSMOSProject25.ipynb" \
       /content/COSMOS25Project/COSMOSProject.ipynb
