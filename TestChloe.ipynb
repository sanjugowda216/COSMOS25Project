# %%
# !git clone https://github.com/sanjugowda216/COSMOS25Project.git
# Out:
# Cloning into 'COSMOS25Project'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 117 (delta 51), reused 23 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 38.58 KiB | 3.51 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
import os
os.environ['GH_TOKEN'] = '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'

# %%
# %%bash
# cd /content/COSMOS25Project
#
# git config user.email "chloeliu150@gmail.com"
# git config user.name  "Chloe Liu"
