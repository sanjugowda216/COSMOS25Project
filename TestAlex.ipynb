# %%
# !git clone https://github.com/sanjugowda216/COSMOS25Project.git
# Out:
# Cloning into 'COSMOS25Project'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 123 (delta 55), reused 26 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 39.98 KiB | 4.44 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
import os
os.environ['GH_TOKEN'] = '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'

# %%
# %%bash
# cd /content/COSMOS25Project
#
# git config user.email "alexparklifestyle@gmail.com"
# git config user.name  "Alex Park"

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/TestAlex.ipynb" \
       /content/COSMOS25Project/TestAlex.ipynb
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/TestAlex.ipynb': No such file or directory
