# %%
token = "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"

# %%
# !git clone https://github.com/sanjugowda216/COSMOS25Project.git
# Out:
# Cloning into 'COSMOS25Project'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 111 (delta 47), reused 20 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (111/111), 36.87 KiB | 599.00 KiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
import os
os.environ['GH_TOKEN'] = "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"

# %%
# %%bash
# cd /content/COSMOS25Project
#
# git config user.email "spgowda216@gmail.com"
# git config user.name  "Sanjana Gowda"

# %%
# adjust the path to wherever you saved it in Drive
# !cp "/content/drive/MyDrive/Colab Notebooks/COSMOSProject25.ipynb" \
       /content/COSMOS25Project/COSMOSProject25.ipynb
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/COSMOSProject25.ipynb': No such file or directory
