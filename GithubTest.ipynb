# %%
import os
os.environ['GH_TOKEN'] = "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"

# %%
# Clone via HTTPS using the token:
# !git clone https://$GH_TOKEN@github.com/sanjugowda216/COSMOS25Project.git
# Out:
# fatal: destination path 'COSMOS25Project' already exists and is not an empty directory.

# %%
# %%bash
# cd /content/COSMOS25Project
#
# git config user.email "hanishdatdood@gmail.com"
# git config user.name  "Hanish Acharla"

# %%
# adjust the path to wherever you saved it in Drive
# !cp "/content/drive/MyDrive/Colab Notebooks/GithubTest.ipynb" \
       /content/COSMOS25Project/NewNotebook.ipynb
# Out:
# ls: cannot access '/content/*.ipynb': No such file or directory
